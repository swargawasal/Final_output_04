# %% [markdown]
# # 🤖 WhatsUpNewYork Auto-Shorts Bot (Colab Edition)
# **Status:** `Stable` | **GPU:** `Supported` | **Env:** `Virtualenv Isolated`
#
# Run this notebook to launch your automation pipeline directly from Google Drive.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import os
import sys

# --- CONFIGURATION ---
# CHANGE THIS PATH to where you uploaded your bot folder in Drive
PROJECT_PATH = "/content/drive/MyDrive/whatsupneyork"
# ---------------------

if not os.path.exists(PROJECT_PATH):
    print(f"❌ Error: Project path not found: {PROJECT_PATH}")
    print("Please upload the bot folder to Google Drive and update the path above.")
else:
    os.chdir(PROJECT_PATH)
    print(f"✅ Working Directory set to: {os.getcwd()}")

# %%
# 2. Environment Setup (Isolated Virtualenv)
# Creates a clean environment to avoid conflicts with Colab pre-installed packages.

# Install System Dependencies
# !apt-get update && apt-get install -y ffmpeg

# Create Virtual Environment
# !pip install virtualenv --quiet
# !rm -rf /content/venv
# !virtualenv -p python3 /content/venv
print("✅ Virtual Environment created at /content/venv")

# Install Python Dependencies (Using venv pip)
# !/content/venv/bin/pip install -r requirements.txt

# Fix OpenCV for Colab (Headless)
# !/content/venv/bin/pip uninstall -y opencv-python opencv-contrib-python
# !/content/venv/bin/pip install opencv-python-headless

# Heal NumPy version for stability
# !/content/venv/bin/pip install "numpy>=1.24.0,<2.0.0" --force-reinstall

# %%
# 3. Launch Bot 🚀
# Runs the main pipeline inside the virtual environment.

# !/content/venv/bin/python main.py
